# %%
import operator

import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures
import pandas as pd

ideal_data = pd.read_csv('data/ideal.csv', index_col=0, delimiter=',')
test_data = pd.read_csv('data/test.csv', index_col=0, delimiter=',')
train_data = pd.read_csv('data/train.csv', index_col=0, delimiter=',')

# Create DataFrames from the CSV files 
ideal_df = pd.DataFrame(ideal_data)/ np.sqrt(np.sum(ideal_data**2))
train_df = pd.DataFrame(train_data)/ np.sqrt(np.sum(train_data**2))

 #minimize the sum of all ydeviations squared (Least-Square)
    
  
for t in range(1,5):
    average_y_deviation = {}  
    largest_deviation = 0
    plt.plot(train_df['y'+str(t)])
    plt.show()
    for x in range(1, 51):
        y1 = train_df['y'+str(t)]
        y2 = ideal_df['y'+str(x)]
        average_y_deviation[x] = np.array(abs(y2-y1)/len(y2))#avg y deviations
        average_y_deviation[x] = np.square(average_y_deviation[x], out=None, where=True, dtype=None).min()
  
  
    key_max = max(average_y_deviation.keys(), key=(lambda k: average_y_deviation[k]))
    key_min = min(average_y_deviation.keys(), key=(lambda k: average_y_deviation[k]))
    
    print(key_max)
# Out:
# 47
# 15
# 4
# 44
